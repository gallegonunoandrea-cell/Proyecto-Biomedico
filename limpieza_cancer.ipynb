# %% [markdown]
# pruebas

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# LIMPIEZA DE DATOS CANCER DE PULMON

# %% [markdown]
# No encontre anomalias en los datos, por lo que no cambie ninguno de ellos

# %%
import pandas as pd
import numpy as np

file_path = r"/content/drive/MyDrive/Colab Notebooks/cancer patient.csv"
data = pd.read_csv(file_path)
data
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
# ...

# %%
data = pd.read_csv(file_path,
               skipfooter=0)
data
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
# ...

# %%
data = pd.read_csv(file_path, usecols=["Age","Gender","Fatigue"])
data
# Out:
#      Age  Gender  Fatigue
# 0     33       1        3
# 1     17       1        1
# 2     35       1        8
# 3     37       1        4
# 4     46       1        3
# ..   ...     ...      ...
# 995   44       1        5
# 996   37       2        9
# 997   25       2        8
# 998   18       2        3
# 999   47       1        8
#
# [1000 rows x 3 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     1000 non-null   int64
#  1   Patient Id                1000 non-null   object
#  2   Age                       1000 non-null   int64
#  3   Gender                    1000 non-null   int64
#  4   Air Pollution             1000 non-null   int64
#  5   Alcohol use               1000 non-null   int64
#  6   Dust Allergy              1000 non-null   int64
#  7   OccuPational Hazards      1000 non-null   int64
#  8   Genetic Risk              1000 non-null   int64
#  9   chronic Lung Disease      1000 non-null   int64
#  10  Balanced Diet             1000 non-null   int64
#  11  Obesity                   1000 non-null   int64
#  12  Smoking                   1000 non-null   int64
#  13  Passive Smoker            1000 non-null   int64
# ...

# %%
data.shape
# Out:
# (1000, 26)

# %%
data.columns
# Out:
# Index(['index', 'Patient Id', 'Age', 'Gender', 'Air Pollution', 'Alcohol use',
#        'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
data.describe(include=[object])
# Out:
#        Patient Id Level
# count        1000  1000
# unique       1000     3
# top          P999  High
# freq            1   365

# %%
data.describe()
# Out:
#              index          Age       Gender  Air Pollution  Alcohol use  \
# count  1000.000000  1000.000000  1000.000000      1000.0000  1000.000000
# mean    499.500000    37.174000     1.402000         3.8400     4.563000
# std     288.819436    12.005493     0.490547         2.0304     2.620477
# min       0.000000    14.000000     1.000000         1.0000     1.000000
# 25%     249.750000    27.750000     1.000000         2.0000     2.000000
# 50%     499.500000    36.000000     1.000000         3.0000     5.000000
# 75%     749.250000    45.000000     2.000000         6.0000     7.000000
# max     999.000000    73.000000     2.000000         8.0000     8.000000
#
#        Dust Allergy  OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count   1000.000000           1000.000000   1000.000000           1000.000000
# mean       5.165000              4.840000      4.580000              4.380000
# ...

# %%
data_sin_duplicados = data.drop_duplicates()
print("DataFRame con duplicados: ", data.shape)
print("DataFrame sin duplicados: ", data_sin_duplicados.shape)
# Out:
# DataFRame con duplicados:  (1000, 26)
# DataFrame sin duplicados:  (1000, 26)

# %% [markdown]
# No tiene datos duplicados

# %%
data_sin_na = data.dropna()
print("DataFRame con na: ", data.shape)
print("DataFrame sin na: ", data_sin_na.shape)
# Out:
# DataFRame con na:  (1000, 26)
# DataFrame sin na:  (1000, 26)

# %%
data.isna()
# Out:
#      index  Patient Id    Age  Gender  Air Pollution  Alcohol use  \
# 0    False       False  False   False          False        False
# 1    False       False  False   False          False        False
# 2    False       False  False   False          False        False
# 3    False       False  False   False          False        False
# 4    False       False  False   False          False        False
# ..     ...         ...    ...     ...            ...          ...
# 995  False       False  False   False          False        False
# 996  False       False  False   False          False        False
# 997  False       False  False   False          False        False
# 998  False       False  False   False          False        False
# 999  False       False  False   False          False        False
#
#      Dust Allergy  OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# 0           False                 False         False                 False
# ...

# %%
data.isna().sum()
# Out:
# index                       0
# Patient Id                  0
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %% [markdown]
# No tiene datos faltantes

# %%
data.min()
# Out:
# index                          0
# Patient Id                    P1
# Age                           14
# Gender                         1
# Air Pollution                  1
# Alcohol use                    1
# Dust Allergy                   1
# OccuPational Hazards           1
# Genetic Risk                   1
# chronic Lung Disease           1
# Balanced Diet                  1
# Obesity                        1
# Smoking                        1
# Passive Smoker                 1
# Chest Pain                     1
# Coughing of Blood              1
# Fatigue                        1
# Weight Loss                    1
# Shortness of Breath            1
# Wheezing                       1
# Swallowing Difficulty          1
# Clubbing of Finger Nails       1
# Frequent Cold                  1
# Dry Cough                      1
# Snoring                        1
# Level                       High
# dtype: object

# %%
data.max()
# Out:
# index                          999
# Patient Id                    P999
# Age                             73
# Gender                           2
# Air Pollution                    8
# Alcohol use                      8
# Dust Allergy                     8
# OccuPational Hazards             8
# Genetic Risk                     7
# chronic Lung Disease             7
# Balanced Diet                    7
# Obesity                          7
# Smoking                          8
# Passive Smoker                   8
# Chest Pain                       9
# Coughing of Blood                9
# Fatigue                          9
# Weight Loss                      8
# Shortness of Breath              9
# Wheezing                         8
# Swallowing Difficulty            8
# Clubbing of Finger Nails         9
# Frequent Cold                    7
# Dry Cough                        7
# Snoring                          7
# Level                       Medium
# dtype: object

# %%
import matplotlib.pyplot as plt
columnas_riesgo = ["Age","Air Pollution","Alcohol use","Dust Allergy","Smoking"]
# Explicitly convert selected columns to float to ensure numeric interpretation for plotting
data[columnas_riesgo].astype(float).plot(kind = "box",subplots=True, layout=(3,2),figsize=(10,8))
plt.suptitle("diagramas de caja de factores de riesgo",y=1.02)
plt.tight_layout()
plt.show()

# %%
data[["Age","Gender"]]
# Out:
#      Age  Gender
# 0     33       1
# 1     17       1
# 2     35       1
# 3     37       1
# 4     46       1
# ..   ...     ...
# 995   44       1
# 996   37       2
# 997   25       2
# 998   18       2
# 999   47       1
#
# [1000 rows x 2 columns]

# %%
data.iloc[0:10,:]
# Out:
#    index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0      0         P1   33       1              2            4             5
# 1      1        P10   17       1              3            1             5
# 2      2       P100   35       1              4            5             6
# 3      3      P1000   37       1              7            7             7
# 4      4       P101   46       1              6            8             7
# 5      5       P102   35       1              4            5             6
# 6      6       P103   52       2              2            4             5
# 7      7       P104   28       2              3            1             4
# 8      8       P105   35       2              4            5             6
# 9      9       P106   46       1              2            3             4
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  ...  Fatigue  \
# ...

# %%
data.iloc[:10,1:4]
# Out:
#   Patient Id  Age  Gender
# 0         P1   33       1
# 1        P10   17       1
# 2       P100   35       1
# 3      P1000   37       1
# 4       P101   46       1
# 5       P102   35       1
# 6       P103   52       2
# 7       P104   28       2
# 8       P105   35       2
# 9       P106   46       1

# %%
data.loc[data["Age"]>35]
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# 6        6       P103   52       2              2            4             5
# 9        9       P106   46       1              2            3             4
# 10      10       P107   44       1              6            7             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 991    991       P991   37       1              8            8             7
# 993    993       P993   37       2              7            7             7
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
# ...

# %%
data.loc[data["Age"]>40, ["Gender","Weight Loss"]]
# Out:
#      Gender  Weight Loss
# 4         1            2
# 6         2            4
# 9         1            2
# 10        1            3
# 11        2            6
# ..      ...          ...
# 979       1            2
# 981       1            2
# 990       1            7
# 995       1            3
# 999       1            7
#
# [341 rows x 2 columns]

# %%
data.sort_values(by=["Age","Alcohol use"])
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 19      19       P115   14       1              2            4             5
# 35      35        P13   14       1              2            4             5
# 130    130       P215   14       1              2            4             5
# 241    241       P315   14       1              2            4             5
# 352    352       P415   14       1              2            4             5
# ..     ...        ...  ...     ...            ...          ...           ...
# 570    570       P611   73       1              5            6             6
# 681    681       P711   73       1              5            6             6
# 792    792       P811   73       1              5            6             6
# 889    889         P9   73       1              5            6             6
# 903    903       P911   73       1              5            6             6
#
# ...

# %%
data = data.drop(data.index[-1])
data
# Out:
#     index Patient Id Age Gender Air Pollution Alcohol use Dust Allergy  \
# 0       0         P1  33      1             2           4            5
# 1       1        P10  17      1             3           1            5
# 2       2       P100  35      1             4           5            6
# 3       3      P1000  37      1             7           7            7
# 4       4       P101  46      1             6           8            7
# ..    ...        ...  ..    ...           ...         ...          ...
# 995   995       P995  44      1             6           7            7
# 996   996       P996  37      2             6           8            7
# 997   997       P997  25      2             4           5            6
# 998   998       P998  18      2             6           8            7
# 999   999       P999  47      1             6           5            6
#
#     OccuPational Hazards Genetic Risk chronic Lung Disease  ...  \
# ...

# %%
data.drop(columns=["sobrepeso","desnutricion"],inplace=True)
data
# Out:
#     index Patient Id Age Gender Air Pollution Alcohol use Dust Allergy  \
# 0       0         P1  33      1             2           4            5
# 1       1        P10  17      1             3           1            5
# 2       2       P100  35      1             4           5            6
# 3       3      P1000  37      1             7           7            7
# 4       4       P101  46      1             6           8            7
# ..    ...        ...  ..    ...           ...         ...          ...
# 995   995       P995  44      1             6           7            7
# 996   996       P996  37      2             6           8            7
# 997   997       P997  25      2             4           5            6
# 998   998       P998  18      2             6           8            7
# 999   999       P999  47      1             6           5            6
#
#     OccuPational Hazards Genetic Risk chronic Lung Disease  ... Fatigue  \
# ...

# %%
data["desnutricion"] = "No"
data
# Out:
#     index Patient Id Age Gender Air Pollution Alcohol use Dust Allergy  \
# 0       0         P1  33      1             2           4            5
# 1       1        P10  17      1             3           1            5
# 2       2       P100  35      1             4           5            6
# 3       3      P1000  37      1             7           7            7
# 4       4       P101  46      1             6           8            7
# ..    ...        ...  ..    ...           ...         ...          ...
# 995   995       P995  44      1             6           7            7
# 996   996       P996  37      2             6           8            7
# 997   997       P997  25      2             4           5            6
# 998   998       P998  18      2             6           8            7
# 999   999       P999  47      1             6           5            6
#
#     OccuPational Hazards Genetic Risk chronic Lung Disease  ... Weight Loss  \
# ...

# %%
data.loc[data["Weight Loss"]>=4, "desnutricion"] = "Si"
data
# Out:
#     index Patient Id Age Gender Air Pollution Alcohol use Dust Allergy  \
# 0       0         P1  33      1             2           4            5
# 1       1        P10  17      1             3           1            5
# 2       2       P100  35      1             4           5            6
# 3       3      P1000  37      1             7           7            7
# 4       4       P101  46      1             6           8            7
# ..    ...        ...  ..    ...           ...         ...          ...
# 995   995       P995  44      1             6           7            7
# 996   996       P996  37      2             6           8            7
# 997   997       P997  25      2             4           5            6
# 998   998       P998  18      2             6           8            7
# 999   999       P999  47      1             6           5            6
#
#     OccuPational Hazards Genetic Risk chronic Lung Disease  ... Weight Loss  \
# ...

# %%
data.drop(columns=["desnutricion"],inplace=True)
data
# Out:
#     index Patient Id Age Gender Air Pollution Alcohol use Dust Allergy  \
# 0       0         P1  33      1             2           4            5
# 1       1        P10  17      1             3           1            5
# 2       2       P100  35      1             4           5            6
# 3       3      P1000  37      1             7           7            7
# 4       4       P101  46      1             6           8            7
# ..    ...        ...  ..    ...           ...         ...          ...
# 995   995       P995  44      1             6           7            7
# 996   996       P996  37      2             6           8            7
# 997   997       P997  25      2             4           5            6
# 998   998       P998  18      2             6           8            7
# 999   999       P999  47      1             6           5            6
#
#     OccuPational Hazards Genetic Risk chronic Lung Disease  ... Fatigue  \
# ...

# %%
data.groupby(["Gender"])["Age"].mean()
# Out:
# Gender
# 1    39.162207
# 2    34.216418
# Name: Age, dtype: object

# %%
data.sort_values(by=["Level"])
# Out:
#     index Patient Id Age Gender Air Pollution Alcohol use Dust Allergy  \
# 999   999       P999  47      1             6           5            6
# 321   321       P388  29      2             4           5            6
# 320   320       P387  19      1             6           8            7
# 319   319       P386  28      1             6           7            7
# 318   318       P385  37      1             6           7            7
# ..    ...        ...  ..    ...           ...         ...          ...
# 409   409       P467  23      1             3           2            4
# 587   587       P627  32      2             1           6            7
# 408   408       P466  35      1             2           1            5
# 178   178       P259  33      1             1           6            7
# 748   748       P772  48      2             6           8            7
#
#     OccuPational Hazards Genetic Risk chronic Lung Disease  ... Fatigue  \
# ...
